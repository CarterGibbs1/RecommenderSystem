# %%
# Tensorflow imports
import tensorflow as tf
import tensorflow_datasets as tfds
import tensorflow_recommenders as tfrs

# Misc
import kagglehub
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import re

# %% [markdown]
# ### Import Data
#
# First download the data from kaggle.
# Then load that data into a dataframe.

# %%
#path = kagglehub.dataset_download("mohamedbakhet/amazon-books-reviews")

# %%
book_data = pd.read_csv('data/books_data.csv')
books_rating_data = pd.read_csv('data/Books_rating.csv')

# %% [markdown]
# ### Explore the dataset

# %%
len(book_data), len(books_rating_data)
# Out:
# (212404, 3000000)

# %%
book_data.columns, books_rating_data.columns
# Out:
# (Index(['Title', 'description', 'authors', 'image', 'previewLink', 'publisher',
#         'publishedDate', 'infoLink', 'categories', 'ratingsCount'],
#        dtype='object'),
#  Index(['Id', 'Title', 'Price', 'User_id', 'profileName', 'review/helpfulness',
#         'review/score', 'review/time', 'review/summary', 'review/text'],
#        dtype='object'))

# %% [markdown]
# #### A look of the Book data

# %%
book_data[:3]
# Out:
#                                    Title  \
# 0         Its Only Art If Its Well Hung!
# 1               Dr. Seuss: American Icon
# 2  Wonderful Worship in Smaller Churches
#
#                                          description           authors  \
# 0                                                NaN  ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 2  This resource includes twelve principles in un...  ['David R. Ray']
#
#                                                image  \
# 0  http://books.google.com/books/content?id=DykPA...
# 1  http://books.google.com/books/content?id=IjvHQ...
# 2  http://books.google.com/books/content?id=2tsDA...
#
#                                          previewLink  publisher publishedDate  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...        NaN          1996
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&p...  A&C Black    2005-01-01
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...        NaN          2000
#
#                                             infoLink  \
# 0  http://books.google.nl/books?id=DykPAAAACAAJ&d...
# 1  http://books.google.nl/books?id=IjvHQsCn_pgC&d...
# 2  http://books.google.nl/books?id=2tsDAAAACAAJ&d...
#
#                       categories  ratingsCount
# 0    ['Comics & Graphic Novels']           NaN
# 1  ['Biography & Autobiography']           NaN
# 2                   ['Religion']           NaN

# %%
book_data.info(), book_data.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 212404 entries, 0 to 212403
# Data columns (total 10 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Title          212403 non-null  object
#  1   description    143962 non-null  object
#  2   authors        180991 non-null  object
#  3   image          160329 non-null  object
#  4   previewLink    188568 non-null  object
#  5   publisher      136518 non-null  object
#  6   publishedDate  187099 non-null  object
#  7   infoLink       188568 non-null  object
#  8   categories     171205 non-null  object
#  9   ratingsCount   49752 non-null   float64
# dtypes: float64(1), object(9)
# memory usage: 16.2+ MB
# (None,
#  Title                 1
#  description       68442
#  authors           31413
#  image             52075
#  previewLink       23836
#  publisher         75886
#  publishedDate     25305
#  infoLink          23836
#  categories        41199
#  ratingsCount     162652
#  dtype: int64)

# %%
book_data.nunique()
# Out:
# Title            212403
# description      133226
# authors          127278
# image            149387
# previewLink      188099
# publisher         16016
# publishedDate     11582
# infoLink         184506
# categories        10883
# ratingsCount        478
# dtype: int64

# %% [markdown]
# Looking into Ratings count

# %%
book_data['ratingsCount'].aggregate(['max', 'min'])
# Out:
# max    4895.0
# min       1.0
# Name: ratingsCount, dtype: float64

# %% [markdown]
# Looking into publisher

# %%
book_data['publisher'].value_counts()
# Out:
# publisher
# Simon and Schuster                                                     3454
# Penguin                                                                2825
# Routledge                                                              2394
# John Wiley & Sons                                                      2031
# Harper Collins                                                         1911
#                                                                        ...
# Georges Boka Editeur                                                      1
# Van Riebeeck Society, The                                                 1
# Post Madison Pub                                                          1
# Honolulu : Department of Anthropology, Bernice Pauahi Bishop Museum       1
# New York : Lothrop, Lee & Shepard                                         1
# Name: count, Length: 16016, dtype: int64

# %% [markdown]
# Looking into author

# %%
book_data['authors'].value_counts()
# Out:
# authors
# ['Rose Arny']                                        236
# ['William Shakespeare']                              191
# ['Library of Congress. Copyright Office']            178
# ['Agatha Christie']                                  142
# ['Erle Stanley Gardner']                             124
#                                                     ...
# ['Nancy Milio']                                        1
# ['Michael Solomon Alexander (bp. of Jerusalem.)']      1
# ['Thacher Hurd', 'John Cassidy']                       1
# ['Bobby Winters']                                      1
# ['Benjamin Friedlander']                               1
# Name: count, Length: 127278, dtype: int64

# %% [markdown]
# #### A look of the Rating data

# %%
books_rating_data[:3]
# Out:
#            Id                           Title  Price         User_id  \
# 0  1882931173  Its Only Art If Its Well Hung!    NaN   AVCGYZL8FQQTD
# 1  0826414346        Dr. Seuss: American Icon    NaN  A30TK6U7DNS82R
# 2  0826414346        Dr. Seuss: American Icon    NaN  A3UH4UZ4RSVO82
#
#              profileName review/helpfulness  review/score  review/time  \
# 0  Jim of Oz "jim-of-oz"                7/7           4.0    940636800
# 1          Kevin Killian              10/10           5.0   1095724800
# 2           John Granger              10/11           5.0   1078790400
#
#                                     review/summary  \
# 0           Nice collection of Julie Strain images
# 1                                Really Enjoyed It
# 2  Essential for every personal and Public Library
#
#                                          review/text
# 0  This is only for Julie Strain fans. It's a col...
# 1  I don't care much for Dr. Seuss but after read...
# 2  If people become the books they read and if "t...

# %%
books_rating_data.info(), books_rating_data.isna().sum()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000000 entries, 0 to 2999999
# Data columns (total 10 columns):
#  #   Column              Dtype
# ---  ------              -----
#  0   Id                  object
#  1   Title               object
#  2   Price               float64
#  3   User_id             object
#  4   profileName         object
#  5   review/helpfulness  object
#  6   review/score        float64
#  7   review/time         int64
#  8   review/summary      object
#  9   review/text         object
# dtypes: float64(2), int64(1), object(7)
# memory usage: 228.9+ MB
# (None,
#  Id                          0
#  Title                     208
#  Price                 2518829
#  User_id                561787
#  profileName            561905
#  review/helpfulness          0
#  review/score                0
#  review/time                 0
#  review/summary            407
#  review/text                 8
#  dtype: int64)

# %%
books_rating_data.nunique()
# Out:
# Id                     221998
# Title                  212403
# Price                    6004
# User_id               1008972
# profileName            854145
# review/helpfulness      12084
# review/score                5
# review/time              6272
# review/summary        1592314
# review/text           2062648
# dtype: int64

# %% [markdown]
# Looking into the data while grouped by the user id, Easier to digest information based on singular users rather than all reviews.

# %%
grouped_by_user = books_rating_data.groupby(by='User_id')

# %%
"""
Perform bayesian average of score based on user
This is because some users only review once and 
never again and this skews individual user review data
"""

def bayesian_avg(s):
    weight = 10
    
    # Calculate the sum of the values and the count of observations
    observed_sum = s.sum()
    observed_count = s.count()
    
    prior_mean = observed_sum / observed_count

    # Calculate the Bayesian average
    bayesian_avg = (observed_sum + prior_mean * weight) / (observed_count + weight)
    
    return bayesian_avg

#grouped_by_user['review/score'].apply(bayesian_avg)

# %% [markdown]
# Looking into data while grouped by the book

# %%
grouped_by_title = books_rating_data.groupby(by='Title')

# %%
#grouped_by_title['review/score'].apply(bayesian_avg)

# %% [markdown]
# Merge data together

# %%
# Remove entries with na as title.
brd = books_rating_data.dropna(subset=('Title'))
bd = book_data.dropna(subset=('Title'))

# %%
# Preprocessing methods
def preprocess_categories(row):
    # If nan
    if isinstance(row, float):
        return ''
    m = re.match(r"\['(.*?)'\]", row)
    if m:
        return m.group(1)
    return ''

# %%
from sklearn.preprocessing import MinMaxScaler
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
# Preprocessing

merged = bd.merge(brd, how='left', on='Title')
merged_book_data = merged[['Title', 'categories', 'review/score', 'description', 'authors']]
merged_book_data.loc[:,'categories'] = merged_book_data['categories'].apply(preprocess_categories)
merged_book_data['description'].fillna('', inplace=True)
merged_book_data['authors'].fillna('', inplace=True)
merged_book_data['combined_text_features'] = '' + merged_book_data['description'] + ' ' + \
    merged_book_data['categories'] + ' ' + merged_book_data['authors']

grouped_by_title = merged_book_data.groupby('Title')

# Average/Normalize Ratings of books
merged_book_data['average rating'] = grouped_by_title['review/score'].transform(lambda x : round(x.mean(), 2))
merged_book_data['average rating'] = MinMaxScaler((0, 5)).fit_transform(merged_book_data[['average rating']])
merged_book_data['Title'] = merged_book_data['Title'].astype('category')

merged_book_data.reset_index(drop=True, inplace=True)
#merged_book_data['average price'] = grouped_by_title.transform() # TODO
# Out:
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:6: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_book_data['description'].fillna('', inplace=True)
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_book_data['description'].fillna('', inplace=True)
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:7: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   merged_book_data['authors'].fillna('', inplace=True)
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_book_data['authors'].fillna('', inplace=True)
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_book_data['combined_text_features'] = '' + merged_book_data['description'] + ' ' + \
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_book_data['average rating'] = grouped_by_title['review/score'].transform(lambda x : round(x.mean(), 2))
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_book_data['average rating'] = MinMaxScaler((0, 5)).fit_transform(merged_book_data[['average rating']])
# C:\Users\carte\AppData\Local\Temp\ipykernel_25200\3356271158.py:16: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   merged_book_data['Title'] = merged_book_data['Title'].astype('category')

# %%
merged_book_data[300:330]
# Out:
#                                                  Title  \
# 300                                 Pyrography Designs
# 301                                 Pyrography Designs
# 302  The ancient constitution and the feudal law,: ...
# 303                   Anna Karenina. (Lernmaterialien)
# 304                                             Seance
# 305                                             Seance
# 306                                             Seance
# 307                                             Seance
# 308      Open marriage;: A new life style for couples,
# 309      Open marriage;: A new life style for couples,
# 310      Open marriage;: A new life style for couples,
# 311      Open marriage;: A new life style for couples,
# 312      Open marriage;: A new life style for couples,
# 313      Open marriage;: A new life style for couples,
# 314      Open marriage;: A new life style for couples,
# 315      Open marriage;: A new life style for couples,
# 316      Open marriage;: A new life style for couples,
# 317      Open marriage;: A new life style for couples,
# 318                        Victoria Magazine July 1994
# 319                 The Ground and Grammar of Theology
# 320                                         Mary, Mary
# 321                                         Mary, Mary
# 322  No place to cry: The hurt and healing of sexua...
# 323  No place to cry: The hurt and healing of sexua...
# 324  No place to cry: The hurt and healing of sexua...
# 325  No place to cry: The hurt and healing of sexua...
# 326  No place to cry: The hurt and healing of sexua...
# 327  No place to cry: The hurt and healing of sexua...
# 328  No place to cry: The hurt and healing of sexua...
# 329                                   Trouble on Titan
#
#                  categories  review/score  \
# 300                     Art           5.0
# 301                     Art           4.0
# 302                 History           4.0
# 303                 Fiction           1.0
# 304                 Fiction           5.0
# 305                 Fiction           5.0
# 306                 Fiction           3.0
# 307                 Fiction           4.0
# 308  Family & Relationships           5.0
# 309  Family & Relationships           5.0
# 310  Family & Relationships           5.0
# 311  Family & Relationships           5.0
# 312  Family & Relationships           1.0
# 313  Family & Relationships           4.0
# 314  Family & Relationships           4.0
# 315  Family & Relationships           3.0
# 316  Family & Relationships           4.0
# 317  Family & Relationships           1.0
# 318    Literary Collections           4.0
# 319                Religion           5.0
# 320         Merchant marine           2.0
# 321         Merchant marine           1.0
# 322                Religion           4.0
# 323                Religion           5.0
# 324                Religion           5.0
# 325                Religion           5.0
# 326                Religion           5.0
# 327                Religion           5.0
# 328                Religion           5.0
# 329                 Fiction           4.0
#
#                                            description  \
# 300  This book offers 30 North American wildlife il...
# 301  This book offers 30 North American wildlife il...
# 302  Pocock explores the relationship between the s...
# 303  De 16-jarige vrienden Red (ik-figuur), Leo, Ro...
# 304  Mysterieus, duister en passioneel Londen, 19de...
# 305  Mysterieus, duister en passioneel Londen, 19de...
# 306  Mysterieus, duister en passioneel Londen, 19de...
# 307  Mysterieus, duister en passioneel Londen, 19de...
# 308  Advocates the importance of individuality in b...
# 309  Advocates the importance of individuality in b...
# 310  Advocates the importance of individuality in b...
# 311  Advocates the importance of individuality in b...
# 312  Advocates the importance of individuality in b...
# 313  Advocates the importance of individuality in b...
# 314  Advocates the importance of individuality in b...
# 315  Advocates the importance of individuality in b...
# 316  Advocates the importance of individuality in b...
# 317  Advocates the importance of individuality in b...
# 318  John Ruskin's 'Sesame and Lilies', first publi...
# 319  The futures seems to be full of promise and ex...
# 320
# 321
# 322  Just as God gave Dorie Van Stone a tender hear...
# 323  Just as God gave Dorie Van Stone a tender hear...
# 324  Just as God gave Dorie Van Stone a tender hear...
# 325  Just as God gave Dorie Van Stone a tender hear...
# 326  Just as God gave Dorie Van Stone a tender hear...
# 327  Just as God gave Dorie Van Stone a tender hear...
# 328  Just as God gave Dorie Van Stone a tender hear...
# 329
#
#                                        authors  \
# 300                            ['Sue Walters']
# 301                            ['Sue Walters']
# 302                        ['J. G. A. Pocock']
# 303                        ['Cara Delevingne']
# 304                        ['Kevin Valgaeren']
# 305                        ['Kevin Valgaeren']
# 306                        ['Kevin Valgaeren']
# 307                        ['Kevin Valgaeren']
# 308         ["Nena O'Neill", "George O'Neill"]
# 309         ["Nena O'Neill", "George O'Neill"]
# 310         ["Nena O'Neill", "George O'Neill"]
# 311         ["Nena O'Neill", "George O'Neill"]
# 312         ["Nena O'Neill", "George O'Neill"]
# 313         ["Nena O'Neill", "George O'Neill"]
# 314         ["Nena O'Neill", "George O'Neill"]
# 315         ["Nena O'Neill", "George O'Neill"]
# 316         ["Nena O'Neill", "George O'Neill"]
# 317         ["Nena O'Neill", "George O'Neill"]
# 318                            ['John Ruskin']
# 319                     ['Thomas F. Torrance']
# 320             ['United States. Coast Guard']
# 321             ['United States. Coast Guard']
# 322  ['Dorie N. Van Stone', 'Erwin W. Lutzer']
# 323  ['Dorie N. Van Stone', 'Erwin W. Lutzer']
# 324  ['Dorie N. Van Stone', 'Erwin W. Lutzer']
# 325  ['Dorie N. Van Stone', 'Erwin W. Lutzer']
# 326  ['Dorie N. Van Stone', 'Erwin W. Lutzer']
# 327  ['Dorie N. Van Stone', 'Erwin W. Lutzer']
# 328  ['Dorie N. Van Stone', 'Erwin W. Lutzer']
# 329                            ['Alan Nourse']
#
#                                 combined_text_features  average rating
# 300  This book offers 30 North American wildlife il...          4.0625
# 301  This book offers 30 North American wildlife il...          4.0625
# 302  Pocock explores the relationship between the s...          3.7500
# 303  De 16-jarige vrienden Red (ik-figuur), Leo, Ro...          0.0000
# 304  Mysterieus, duister en passioneel Londen, 19de...          4.0625
# 305  Mysterieus, duister en passioneel Londen, 19de...          4.0625
# 306  Mysterieus, duister en passioneel Londen, 19de...          4.0625
# 307  Mysterieus, duister en passioneel Londen, 19de...          4.0625
# 308  Advocates the importance of individuality in b...          3.3750
# 309  Advocates the importance of individuality in b...          3.3750
# 310  Advocates the importance of individuality in b...          3.3750
# 311  Advocates the importance of individuality in b...          3.3750
# 312  Advocates the importance of individuality in b...          3.3750
# 313  Advocates the importance of individuality in b...          3.3750
# 314  Advocates the importance of individuality in b...          3.3750
# 315  Advocates the importance of individuality in b...          3.3750
# 316  Advocates the importance of individuality in b...          3.3750
# 317  Advocates the importance of individuality in b...          3.3750
# 318  John Ruskin's 'Sesame and Lilies', first publi...          3.7500
# 319  The futures seems to be full of promise and ex...          5.0000
# 320     Merchant marine ['United States. Coast Guard']          0.6250
# 321     Merchant marine ['United States. Coast Guard']          0.6250
# 322  Just as God gave Dorie Van Stone a tender hear...          4.8250
# 323  Just as God gave Dorie Van Stone a tender hear...          4.8250
# 324  Just as God gave Dorie Van Stone a tender hear...          4.8250
# 325  Just as God gave Dorie Van Stone a tender hear...          4.8250
# 326  Just as God gave Dorie Van Stone a tender hear...          4.8250
# 327  Just as God gave Dorie Van Stone a tender hear...          4.8250
# 328  Just as God gave Dorie Van Stone a tender hear...          4.8250
# 329                            Fiction ['Alan Nourse']          4.3750

# %%
# Compute similarity of text features
tfidf = TfidfVectorizer(stop_words='english')
tfidf_matrix = tfidf.fit_transform(merged_book_data['combined_text_features'])

#merged_book_data.drop(['review/score', 'description', 'authors', 'categories'],axis=1, inplace=True)
#merged_book_data.drop_duplicates(inplace=True)

# %%
merged_book_data[:5]
# Out:
#                             Title                 categories  review/score  \
# 0  Its Only Art If Its Well Hung!    Comics & Graphic Novels           4.0
# 1        Dr. Seuss: American Icon  Biography & Autobiography           5.0
# 2        Dr. Seuss: American Icon  Biography & Autobiography           5.0
# 3        Dr. Seuss: American Icon  Biography & Autobiography           4.0
# 4        Dr. Seuss: American Icon  Biography & Autobiography           4.0
#
#                                          description           authors  \
# 0                                                     ['Julie Strain']
# 1  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 2  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 3  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
# 4  Philip Nel takes a fascinating look into the k...    ['Philip Nel']
#
#                               combined_text_features  average rating
# 0           Comics & Graphic Novels ['Julie Strain']            3.75
# 1  Philip Nel takes a fascinating look into the k...            4.45
# 2  Philip Nel takes a fascinating look into the k...            4.45
# 3  Philip Nel takes a fascinating look into the k...            4.45
# 4  Philip Nel takes a fascinating look into the k...            4.45

# %%
tfidf_matrix
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 138751918 stored elements and shape (2999792, 236277)>

# %% [markdown]
# ### Feature Engineering

# %% [markdown]
# Most of the features initially will be removed as to simplify the recommender system

# %% [markdown]
# ### Data Formatting - Tensorflow

# %% [markdown]
# Set up a shuffled dataset

# %%
#ratings_tf = tf.data.Dataset.from_tensor_slices(dict(merged_book_data))

# %%
#tf.random.set_seed(42)
#shuffled = ratings_tf.shuffle(100_000, seed=42, reshuffle_each_iteration=False)

#train = shuffled.take(80_000)
#test = shuffled.skip(80_000).take(20_000)

# %%
#final_data = merged_book_data.set_index(merged_book_data['Title'])
#final_data = final_data.drop('Title', axis=1)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.model_selection import train_test_split

X = tfidf_matrix

X_train, X_test = train_test_split(X, random_state=1)

#ohe = OneHotEncoder(handle_unknown='ignore')
#X_train = ohe.fit_transform(X_train)
#X_test = ohe.transform(X_test)

#encoded_data = merged_book_data

# %%
X_train[0]
# Out:
# <Compressed Sparse Row sparse matrix of dtype 'float64'
# 	with 23 stored elements and shape (1, 236277)>

# %% [markdown]
# ### Building Recommender System - Tensorflow

# %% [markdown]
# This recommender system will use an embedding model for the model to learn embeddings unsupervised and then from these embeddings run KNN.
#
# First, I'm going to set up a base case of just running KNN.

# %%
from sklearn.neighbors import NearestNeighbors

knn = NearestNeighbors(metric='cosine')
knn.fit(X_train)
# Out:
# NearestNeighbors(metric='cosine')

# %%
def recommend_books_knn(title, books_data, knn_model, tfidf_matrix, n_recommendations=5):
    idx = books_data[books_data['Title'] == title].index[0]
    book_vector = tfidf_matrix[idx]
    distances, indices = knn_model.kneighbors(book_vector, n_neighbors=n_recommendations+1)
    
    recommended_indices = indices[0][1:]
    recommendations = books_data.iloc[recommended_indices]
    return recommendations

# %%
merged_book_data[550:600]
# Out:
#                                                  Title            categories  \
# 550                 America at 1750: A Social Portrait               History
# 551                                        Death Dream   Body, Mind & Spirit
# 552                                        Death Dream   Body, Mind & Spirit
# 553                                        Death Dream   Body, Mind & Spirit
# 554                                        Death Dream   Body, Mind & Spirit
# 555                                        Death Dream   Body, Mind & Spirit
# 556                                        Death Dream   Body, Mind & Spirit
# 557                                        Death Dream   Body, Mind & Spirit
# 558                                        Death Dream   Body, Mind & Spirit
# 559                                        Death Dream   Body, Mind & Spirit
# 560                                        Death Dream   Body, Mind & Spirit
# 561                                        Death Dream   Body, Mind & Spirit
# 562                                        Death Dream   Body, Mind & Spirit
# 563                                        Death Dream   Body, Mind & Spirit
# 564                                        Death Dream   Body, Mind & Spirit
# 565                                        Death Dream   Body, Mind & Spirit
# 566                                        Death Dream   Body, Mind & Spirit
# 567                                        Death Dream   Body, Mind & Spirit
# 568                                        Death Dream   Body, Mind & Spirit
# 569                                        Death Dream   Body, Mind & Spirit
# 570                                        Death Dream   Body, Mind & Spirit
# 571                                        Death Dream   Body, Mind & Spirit
# 572                                        Death Dream   Body, Mind & Spirit
# 573                                        Death Dream   Body, Mind & Spirit
# 574                                        Death Dream   Body, Mind & Spirit
# 575                                        Death Dream   Body, Mind & Spirit
# 576  Information Theory in Analytical Chemistry (Ch...               Science
# 577  Alternative Chicago: Unique Destinations Beyon...               History
# 578  Alternative Chicago: Unique Destinations Beyon...               History
# 579                                       Sleeping Boy
# 580                                       Sleeping Boy
# 581                                       Sleeping Boy
# 582                                       Sleeping Boy
# 583                                       Sleeping Boy
# 584  The Civil War Recollections of General Ellis S...               History
# 585  The Civil War Recollections of General Ellis S...               History
# 586   Handbook of Environmental and Resource Economics  Business & Economics
# 587                                   The Food Of Love               Fiction
# 588                                   The Food Of Love               Fiction
# 589                                   The Food Of Love               Fiction
# 590                                   The Food Of Love               Fiction
# 591                                   The Food Of Love               Fiction
# 592                                   The Food Of Love               Fiction
# 593                                   The Food Of Love               Fiction
# 594                                   The Food Of Love               Fiction
# 595                                   The Food Of Love               Fiction
# 596                                   The Food Of Love               Fiction
# 597                                   The Food Of Love               Fiction
# 598                                   The Food Of Love               Fiction
# 599                                   The Food Of Love               Fiction
#
#      review/score                                        description  \
# 550           2.0  Demonstrates how the colonies developed into t...
# 551           5.0  The authors probe the phenomenon of "pre-death...
# 552           3.0  The authors probe the phenomenon of "pre-death...
# 553           4.0  The authors probe the phenomenon of "pre-death...
# 554           4.0  The authors probe the phenomenon of "pre-death...
# 555           5.0  The authors probe the phenomenon of "pre-death...
# 556           3.0  The authors probe the phenomenon of "pre-death...
# 557           1.0  The authors probe the phenomenon of "pre-death...
# 558           4.0  The authors probe the phenomenon of "pre-death...
# 559           4.0  The authors probe the phenomenon of "pre-death...
# 560           4.0  The authors probe the phenomenon of "pre-death...
# 561           5.0  The authors probe the phenomenon of "pre-death...
# 562           1.0  The authors probe the phenomenon of "pre-death...
# 563           5.0  The authors probe the phenomenon of "pre-death...
# 564           4.0  The authors probe the phenomenon of "pre-death...
# 565           4.0  The authors probe the phenomenon of "pre-death...
# 566           3.0  The authors probe the phenomenon of "pre-death...
# 567           1.0  The authors probe the phenomenon of "pre-death...
# 568           4.0  The authors probe the phenomenon of "pre-death...
# 569           4.0  The authors probe the phenomenon of "pre-death...
# 570           4.0  The authors probe the phenomenon of "pre-death...
# 571           5.0  The authors probe the phenomenon of "pre-death...
# 572           1.0  The authors probe the phenomenon of "pre-death...
# 573           5.0  The authors probe the phenomenon of "pre-death...
# 574           4.0  The authors probe the phenomenon of "pre-death...
# 575           4.0  The authors probe the phenomenon of "pre-death...
# 576           4.0  Demonstrates how the information theory approa...
# 577           5.0  ""Alternative Chicago"" is for the young-at-he...
# 578           1.0  ""Alternative Chicago"" is for the young-at-he...
# 579           5.0
# 580           5.0
# 581           5.0
# 582           3.0
# 583           1.0
# 584           5.0
# 585           5.0
# 586           5.0  This major reference book comprises specially ...
# 587           5.0  Een heerlijke roman over culinaire verleiding ...
# 588           5.0  Een heerlijke roman over culinaire verleiding ...
# 589           4.0  Een heerlijke roman over culinaire verleiding ...
# 590           5.0  Een heerlijke roman over culinaire verleiding ...
# 591           4.0  Een heerlijke roman over culinaire verleiding ...
# 592           4.0  Een heerlijke roman over culinaire verleiding ...
# 593           3.0  Een heerlijke roman over culinaire verleiding ...
# 594           5.0  Een heerlijke roman over culinaire verleiding ...
# 595           4.0  Een heerlijke roman over culinaire verleiding ...
# 596           4.0  Een heerlijke roman over culinaire verleiding ...
# 597           4.0  Een heerlijke roman over culinaire verleiding ...
# 598           5.0  Een heerlijke roman over culinaire verleiding ...
# 599           5.0  Een heerlijke roman over culinaire verleiding ...
#
#                                     authors  \
# 550                  ['Richard Hofstadter']
# 551  ['Kelly Bulkeley', 'Patricia Bulkley']
# 552  ['Kelly Bulkeley', 'Patricia Bulkley']
# 553  ['Kelly Bulkeley', 'Patricia Bulkley']
# 554  ['Kelly Bulkeley', 'Patricia Bulkley']
# 555  ['Kelly Bulkeley', 'Patricia Bulkley']
# 556  ['Kelly Bulkeley', 'Patricia Bulkley']
# 557  ['Kelly Bulkeley', 'Patricia Bulkley']
# 558  ['Kelly Bulkeley', 'Patricia Bulkley']
# 559  ['Kelly Bulkeley', 'Patricia Bulkley']
# 560  ['Kelly Bulkeley', 'Patricia Bulkley']
# 561  ['Kelly Bulkeley', 'Patricia Bulkley']
# 562  ['Kelly Bulkeley', 'Patricia Bulkley']
# 563  ['Kelly Bulkeley', 'Patricia Bulkley']
# 564  ['Kelly Bulkeley', 'Patricia Bulkley']
# 565  ['Kelly Bulkeley', 'Patricia Bulkley']
# 566  ['Kelly Bulkeley', 'Patricia Bulkley']
# 567  ['Kelly Bulkeley', 'Patricia Bulkley']
# 568  ['Kelly Bulkeley', 'Patricia Bulkley']
# 569  ['Kelly Bulkeley', 'Patricia Bulkley']
# 570  ['Kelly Bulkeley', 'Patricia Bulkley']
# 571  ['Kelly Bulkeley', 'Patricia Bulkley']
# 572  ['Kelly Bulkeley', 'Patricia Bulkley']
# 573  ['Kelly Bulkeley', 'Patricia Bulkley']
# 574  ['Kelly Bulkeley', 'Patricia Bulkley']
# 575  ['Kelly Bulkeley', 'Patricia Bulkley']
# 576   ['Karel Eckschlager', 'Klaus Danzer']
# 577                          ['Bill Franz']
# 578                          ['Bill Franz']
# 579                     ['L. V. H. Crosby']
# 580                     ['L. V. H. Crosby']
# 581                     ['L. V. H. Crosby']
# 582                     ['L. V. H. Crosby']
# 583                     ['L. V. H. Crosby']
# 584                         ['Ellis Spear']
# 585                         ['Ellis Spear']
# 586       ['Jeroen C. J. M. Van den Bergh']
# 587                     ['Anthony Capella']
# 588                     ['Anthony Capella']
# 589                     ['Anthony Capella']
# 590                     ['Anthony Capella']
# 591                     ['Anthony Capella']
# 592                     ['Anthony Capella']
# 593                     ['Anthony Capella']
# 594                     ['Anthony Capella']
# 595                     ['Anthony Capella']
# 596                     ['Anthony Capella']
# 597                     ['Anthony Capella']
# 598                     ['Anthony Capella']
# 599                     ['Anthony Capella']
#
#                                 combined_text_features  average rating
# 550  Demonstrates how the colonies developed into t...           3.475
# 551  The authors probe the phenomenon of "pre-death...           3.300
# 552  The authors probe the phenomenon of "pre-death...           3.300
# 553  The authors probe the phenomenon of "pre-death...           3.300
# 554  The authors probe the phenomenon of "pre-death...           3.300
# 555  The authors probe the phenomenon of "pre-death...           3.300
# 556  The authors probe the phenomenon of "pre-death...           3.300
# 557  The authors probe the phenomenon of "pre-death...           3.300
# 558  The authors probe the phenomenon of "pre-death...           3.300
# 559  The authors probe the phenomenon of "pre-death...           3.300
# 560  The authors probe the phenomenon of "pre-death...           3.300
# 561  The authors probe the phenomenon of "pre-death...           3.300
# 562  The authors probe the phenomenon of "pre-death...           3.300
# 563  The authors probe the phenomenon of "pre-death...           3.300
# 564  The authors probe the phenomenon of "pre-death...           3.300
# 565  The authors probe the phenomenon of "pre-death...           3.300
# 566  The authors probe the phenomenon of "pre-death...           3.300
# 567  The authors probe the phenomenon of "pre-death...           3.300
# 568  The authors probe the phenomenon of "pre-death...           3.300
# 569  The authors probe the phenomenon of "pre-death...           3.300
# 570  The authors probe the phenomenon of "pre-death...           3.300
# 571  The authors probe the phenomenon of "pre-death...           3.300
# 572  The authors probe the phenomenon of "pre-death...           3.300
# 573  The authors probe the phenomenon of "pre-death...           3.300
# 574  The authors probe the phenomenon of "pre-death...           3.300
# 575  The authors probe the phenomenon of "pre-death...           3.300
# 576  Demonstrates how the information theory approa...           3.750
# 577  ""Alternative Chicago"" is for the young-at-he...           2.500
# 578  ""Alternative Chicago"" is for the young-at-he...           2.500
# 579                                ['L. V. H. Crosby']           3.500
# 580                                ['L. V. H. Crosby']           3.500
# 581                                ['L. V. H. Crosby']           3.500
# 582                                ['L. V. H. Crosby']           3.500
# 583                                ['L. V. H. Crosby']           3.500
# 584                            History ['Ellis Spear']           5.000
# 585                            History ['Ellis Spear']           5.000
# 586  This major reference book comprises specially ...           5.000
# 587  Een heerlijke roman over culinaire verleiding ...           3.850
# 588  Een heerlijke roman over culinaire verleiding ...           3.850
# 589  Een heerlijke roman over culinaire verleiding ...           3.850
# 590  Een heerlijke roman over culinaire verleiding ...           3.850
# 591  Een heerlijke roman over culinaire verleiding ...           3.850
# 592  Een heerlijke roman over culinaire verleiding ...           3.850
# 593  Een heerlijke roman over culinaire verleiding ...           3.850
# 594  Een heerlijke roman over culinaire verleiding ...           3.850
# 595  Een heerlijke roman over culinaire verleiding ...           3.850
# 596  Een heerlijke roman over culinaire verleiding ...           3.850
# 597  Een heerlijke roman over culinaire verleiding ...           3.850
# 598  Een heerlijke roman over culinaire verleiding ...           3.850
# 599  Een heerlijke roman over culinaire verleiding ...           3.850

# %%
example_title = merged_book_data['Title'].iloc[576]
matrix = recommend_books_knn(example_title, merged_book_data, knn, tfidf_matrix)
print("Recommending books based on: ", example_title)
matrix
# Out:
# Recommending books based on:  Information Theory in Analytical Chemistry (Chemical Analysis: A Series of Monographs on Analytical Chemistry and Its Applications)
#                                         Title        categories  review/score  \
# 64792                                   Night  Juvenile Fiction           5.0
# 1209221  Midnight Secrets (Berkley Sensation)                             5.0
# 1262219             We never went to the moon                             3.0
# 338198                     A Clockwork Orange  Juvenile Fiction           5.0
# 65222                                   Night  Juvenile Fiction           4.0
#
#                                                description  \
# 64792    Here is the wonderful new version of the class...
# 1209221
# 1262219
# 338198   In de nabije toekomst maken jongeren de strate...
# 65222    Here is the wonderful new version of the class...
#
#                      authors  \
# 64792      ['Clement Moore']
# 1209221
# 1262219
# 338198   ['Anthony Burgess']
# 65222      ['Clement Moore']
#
#                                     combined_text_features  average rating
# 64792    Here is the wonderful new version of the class...          4.4625
# 1209221                                                             4.2000
# 1262219                                                             2.0625
# 338198   In de nabije toekomst maken jongeren de strate...          4.4625
# 65222    Here is the wonderful new version of the class...          4.4625
